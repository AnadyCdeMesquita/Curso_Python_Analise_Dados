# %%
import numpy as np

dados = np.array([10, 15, 20, 30, 40, 50,])

dados[dados < 20] = 0
print(dados)

dados2 = np.array([10, 15, 20, 30, 40, 50,])
print(dados2[dados2 > 25], dados >20)
print(dados2[dados2 == 20]) # expoe os numero 
print(dados2  == 20) # false ou true
# Out:
# [ 0  0 20 30 40 50]
# [30 40 50] [False False False  True  True  True]
# [20]
# [False False  True False False False]

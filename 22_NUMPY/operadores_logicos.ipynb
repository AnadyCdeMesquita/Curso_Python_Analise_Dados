# %%
import numpy as np

dados = np.array([10, 20, 30, 40, 50])
print((dados > 20) & (dados < 50))
print((dados < 20) | (dados < 50))
# Out:
# [False False  True  True False]
# [ True  True  True  True False]

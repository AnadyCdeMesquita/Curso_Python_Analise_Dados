# %%
import pandas as pd
import numpy as np

lista1 = [1, 2, 3, 4, 5, 6]

array1 = np.array(lista1)
print(array1)

meu_array = np.array([10, 20, 30, 40, 50])
print('Tipo de Array:', meu_array.dtype) #tipo de array
print('Tamanho do Array:', meu_array.size) #tamanho do array
print('Dimensão do Array:', meu_array.ndim) #dimensão do array
print('Formato do Array:', meu_array.shape) #formato do array
# Out:
# [1 2 3 4 5 6]
# Tipo de Array: int64
# Tamanho do Array: 5
# Dimensão do Array: 1
# Formato do Array: (5,)

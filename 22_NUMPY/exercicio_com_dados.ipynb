# %%
import numpy as np


dado1 = np.random.randint(1, 7, 10)
dado2 = np.random.randint(1, 7, 10)

print(f'Dado_1: {dado1}')
print(f'Dado_2: {dado2}')
soma = dado1 + dado2
print(f'A soma é: {soma}')

# vencedor = np.argmax(soma) + 1 
# print(f'O vencedor é : {vencedor}')

vencedor2 = np.where(soma == soma.max())[0] +1
print(f'O vencedor é {vencedor2}')
# Out:
# Dado_1: [6 4 4 4 1 2 4 6 2 5]
# Dado_2: [3 4 3 1 2 3 5 1 5 1]
# A soma é: [9 8 7 5 3 5 9 7 7 6]
# O vencedor é [1 7]

# %%
import numpy as np

# Um único número (de 0 até o limite):teste = np.random.randint(10) — 
# Gera um número entre 0 e 9 (o limite superior é exclusivo).
# Um intervalo específico:teste = np.random.randint(5, 15) — Gera um número entre 5 e 14.
# Uma lista ou matr(usando o parâmetro size):teste = np.random.randint(0, 10, size=5) — Gera uma lista com 5 números aleatórios entre 0 e 9.

# %%
teste = np.random.randint(0, 10) 
print(teste)

teste1 = np.random.randint(0, 10, size=5)
print(teste1)
# Out:
# 7
# [8 9 9 4 7]

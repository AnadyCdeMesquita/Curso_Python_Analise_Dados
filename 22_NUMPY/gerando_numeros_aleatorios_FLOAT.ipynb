# %%
import numpy as np

teste = np.random.rand() # gera numero float de 0(incluso) a 1(excluso)
print(teste)

teste2 = np.random.rand(5)
print(teste2)

matriz = np.random.rand(2,3)
print(matriz)
# Out:
# 0.33739565966018736
# [0.65870282 0.60161265 0.32007781 0.54761747 0.53317629]
# [[0.25313751 0.93582299 0.70976944]
#  [0.77803232 0.74293063 0.7161345 ]]

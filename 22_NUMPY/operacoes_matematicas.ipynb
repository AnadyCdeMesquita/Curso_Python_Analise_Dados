# %%
import numpy as np

a = np.array([10, 20, 30, 40 ])
b = np.array([1, 2, 3, 4])

print('adição = ', a + b)
print('subtração = ', a - b)
print('multiplicação = ', a * b)
print('divisão = ', a / b)
print('potenciação = ', a**b)
# Out:
# adição =  [11 22 33 44]
# subtração =  [ 9 18 27 36]
# multiplicação =  [ 10  40  90 160]
# divisão =  [10. 10. 10. 10.]
# potenciação =  [     10     400   27000 2560000]

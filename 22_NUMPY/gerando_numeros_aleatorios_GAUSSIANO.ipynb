# %%
import numpy as np

teste = np.random.randn(10)
print(teste)

teste1 = np.random.randn()
print(teste1)

matriz = np.random.randn(2, 3)
print(matriz)
# Out:
# [ 0.14739596  0.17188141  2.13081435 -1.03181275  2.80595194  0.8432576
#   1.26482973  0.31024412  1.23840719  1.44502342]
# 0.10472828315343861
# [[ 0.79434424 -0.17419135 -0.50576806]
#  [-1.0933715   0.45635927 -0.28760885]]

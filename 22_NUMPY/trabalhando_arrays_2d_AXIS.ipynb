# %%
import numpy as np

notas = np.array([[8.0, 7.5, 9.0], 
                  [6.0, 5.5, 7.0], 
                  [9.5, 8.5, 10.0]])

print('media:',notas.mean())
print('media:',notas.mean(axis= 0)) # linhas
print('media:',notas.mean(axis = 1)) #colunas
# Out:
# media: 7.888888888888889
# media: [7.83333333 7.16666667 8.66666667]
# media: [8.16666667 6.16666667 9.33333333]

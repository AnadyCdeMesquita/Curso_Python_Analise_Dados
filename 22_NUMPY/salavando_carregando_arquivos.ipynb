# %%
import numpy as np

numeros_uniformes = np.random.uniform(10.5, 20.5, 5)
print(numeros_uniformes)

salvando = np.save('numeros_uniformes.npy', numeros_uniformes) #arquivo binário
# Out:
# [20.03430952 14.62300274 16.40413623 19.91691195 11.0726359 ]

# %%
baixando = np.load('numeros_uniformes.npy') #lê somente aqui 
print(baixando)
# Out:
# [20.03430952 14.62300274 16.40413623 19.91691195 11.0726359 ]
